# %%
import sys
print(f"Python path: {sys.executable}")
print("Jupyter is working in VSCodium!")
# Out:
# Python path: /home/jesse/...me/notebooks/jupyter/jupyter-env/bin/python
# Jupyter is working in VSCodium!
